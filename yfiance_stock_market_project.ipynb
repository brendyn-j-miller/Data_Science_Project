# %% [markdown]
# <a href="https://colab.research.google.com/github/brendyn-j-miller/Data_Science_Project/blob/master/yfiance_stock_market_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install yfinance before you use it.
# !pip install yfinance
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22409 sha256=ad79fa241ef48a66a7a4a9addd8e61e7b0954354946dd058f58c1891b1eaa930
#   Stored in directory: /root/.cache/pip/wheels/f9/e3/5b/ec24dd2984b12d61e0abf26289746c2436a0e7844f26f2515c
# Successfully built yfinance
# ...

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get stock info
print(msft.info)

# get historical market data
hist = msft.history(period="1y")
# Out:
# {'zip': '98052', 'sector': 'Technology', 'fullTimeEmployees': 144000, 'longBusinessSummary': 'Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. Its Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, and Skype for Business, as well as related Client Access Licenses (CAL); Skype, Outlook.com, and OneDrive; LinkedIn that includes Talent and marketing solutions, and subscriptions; and Dynamics 365, a set of cloud-based and on-premises business solutions for small and medium businesses, large organizations, and divisions of enterprises. Its Intelligent Cloud segment licenses SQL and Windows Servers, Visual Studio, System Center, and related CALs; GitHub that provides a collaboration platform and code hosting service for developers; and Azure, a cloud platform. It also provides support services and Microsoft consulting services to assist customers in
# ...

# %%
import matplotlib.pyplot as plt
import seaborn
# Plot everything by leveraging the matplotlib package
hist['Close'].plot(figsize=(16, 9))
plt.title('Closing Prices for MSFT for the past year')
plt.ylabel('Closing Price of Stock per Share ($)')
# Out:
# Text(0, 0.5, 'Closing Price of Stock per Share ($)')

# %%
# Download stock data and then export as CSV
data_df = yf.download("AAPL", start = "2020-02-01", end = "2020-03-20")
data_df.to_csv('aapl.csv')

# %%
# show actions (dividends, splits)
msft.actions
# Out:
#             Dividends  Stock Splits
# Date
# 2019-08-14       0.46           0.0
# 2019-11-20       0.51           0.0
# 2020-02-19       0.51           0.0
# 2020-05-20       0.51           0.0
